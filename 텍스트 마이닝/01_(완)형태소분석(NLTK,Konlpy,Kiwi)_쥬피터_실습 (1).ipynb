# %% [markdown]
# ## 1. 형태소분석 : NLTK

# %%
#nltk 설치하기
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\002\anaconda3\lib\site-packages (3.9.1)
# Requirement already satisfied: click in c:\users\002\anaconda3\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\002\anaconda3\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\002\anaconda3\lib\site-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in c:\users\002\anaconda3\lib\site-packages (from nltk) (4.66.5)
# Requirement already satisfied: colorama in c:\users\002\anaconda3\lib\site-packages (from click->nltk) (0.4.6)

# %%
#nltk 실행하기
import nltk
nltk.download("punkt")
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\002\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\002\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\002\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# True

# %%
#샘플 텍스트
text = 'The little yellow dog barked at the Persian cat'

# %%
split_text = nltk.word_tokenize(text)
tagged_text = nltk.pos_tag(split_text)
tagged_text
# Out:
# [('The', 'DT'),
#  ('little', 'JJ'),
#  ('yellow', 'JJ'),
#  ('dog', 'NN'),
#  ('barked', 'VBD'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('Persian', 'JJ'),
#  ('cat', 'NN')]

# %% [markdown]
# ##### ♦️1. 실습예제
#   - 명사만 추출하는 define 함수를 만들어보자!

# %%
def nltk_noun(string):
    split_text = nltk.word_tokenize(string)
    tagged_text = nltk.pos_tag(split_text)

    # result=[]
    # for word, tag in tagged_text:
    #     if tag in {'NN', 'NNS', 'NNP', 'NNPS'}:
    #         result.append(word)
    
    result = [word for word, tag in tagged_text if tag in {'NN', 'NNS', 'NNP', 'NNPS'} ]
    
    return result

# %%
nltk_noun('Hello My name is HyunJin')
# Out:
# ['Hello', 'My', 'name', 'HyunJin']

# %% [markdown]
# ### 2.1. NLTK 불용어 사용하기

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\002\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stopwords = nltk.corpus.stopwords.words('english')
stopwords
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she'd",
#  "she'll",
#  "she's",
#  'should',
#  'shouldn',
#  "shouldn't",
#  "should've",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  "they'd",
#  "they'll",
#  "they're",
#  "they've",
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  "we'd",
#  "we'll",
#  "we're",
#  'were',
#  'weren',
#  "weren't",
#  "we've",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  'your',
#  "you're",
#  'yours',
#  'yourself',
#  'yourselves',
#  "you've"]

# %% [markdown]
# ### 2.2 소문자변환

# %%
string = 'Are you Enjoying The Class?'

# %%
string.lower()
# Out:
# 'are you enjoying the class?'

# %%
'Are you Enjoying The Class?'.lower()
# Out:
# 'are you enjoying the class?'

# %% [markdown]
# ##### ♦️2. 실습예제
#   - 영어 불용어 적용 명사 define 만들기

# %%
def extract_noun_english(string):
    string = string.lower()
    split_text = nltk.word_tokenize(string)
    tagged_text = nltk.pos_tag(split_text)

    # result = []
    # for word, tag in tagged_text:
    #     if word not in stopwords:
    #         if tag in {'NN', 'NNS', 'NNP', 'NNPS'}:
    #             result.append(word)

    result =[word for word, tag in tagged_text if word not in stopwords if tag in {'NN', 'NNS', 'NNP', 'NNPS'}]
    return result

# %%
extract_noun_english('I am Happy girl')
# Out:
# ['girl']

# %% [markdown]
# ## 2. 형태소분석 : Konlpy

# %%
## 코랩 konlpy 실행
# !curl -s https://raw.githubusercontent.com/teddylee777/machine-learning/master/99-Misc/01-Colab/mecab-colab.sh | bash

# %%
from konlpy.tag import Okt
okt=Okt()

# %%
text ='오늘 나는 친구랑 영화를 볼 것이다.'

# %%
okt.morphs(text)
# Out:
# ['오늘', '나', '는', '친구', '랑', '영화', '를', '볼', '것', '이다', '.']

# %%
okt.nouns(text)
# Out:
# ['오늘', '나', '친구', '영화', '볼', '것']

# %%
okt.pos(text)
# Out:
# [('오늘', 'Noun'),
#  ('나', 'Noun'),
#  ('는', 'Josa'),
#  ('친구', 'Noun'),
#  ('랑', 'Josa'),
#  ('영화', 'Noun'),
#  ('를', 'Josa'),
#  ('볼', 'Noun'),
#  ('것', 'Noun'),
#  ('이다', 'Josa'),
#  ('.', 'Punctuation')]

# %%
okt.tagset
# Out:
# {'Adjective': '형용사',
#  'Adverb': '부사',
#  'Alpha': '알파벳',
#  'Conjunction': '접속사',
#  'Determiner': '관형사',
#  'Eomi': '어미',
#  'Exclamation': '감탄사',
#  'Foreign': '외국어, 한자 및 기타기호',
#  'Hashtag': '트위터 해쉬태그',
#  'Josa': '조사',
#  'KoreanParticle': '(ex: ㅋㅋ)',
#  'Noun': '명사',
#  'Number': '숫자',
#  'PreEomi': '선어말어미',
#  'Punctuation': '구두점',
#  'ScreenName': '트위터 아이디',
#  'Suffix': '접미사',
#  'Unknown': '미등록어',
#  'Verb': '동사'}

# %%
#norm
text = '맛있는 사과를 먹을 거닼ㅋㅋㅋㅋㅋㅋ'
okt.pos(text, norm=True)
# Out:
# [('맛있는', 'Adjective'),
#  ('사과', 'Noun'),
#  ('를', 'Josa'),
#  ('먹을', 'Verb'),
#  ('거', 'Noun'),
#  ('다', 'Josa'),
#  ('ㅋㅋㅋ', 'KoreanParticle')]

# %%
#stem
text = '맛있는 사과를 먹을 것이다.'
okt.pos(text, stem=True)
# Out:
# [('맛있다', 'Adjective'),
#  ('사과', 'Noun'),
#  ('를', 'Josa'),
#  ('먹다', 'Verb'),
#  ('것', 'Noun'),
#  ('이다', 'Josa'),
#  ('.', 'Punctuation')]

# %%
text = '맛있는 사과를 먹을 것이닼ㅋㅋㅋ.'
okt.pos(text, norm=True, stem=True)
# Out:
# [('맛있다', 'Adjective'),
#  ('사과', 'Noun'),
#  ('를', 'Josa'),
#  ('먹다', 'Verb'),
#  ('것', 'Noun'),
#  ('이다', 'Josa'),
#  ('ㅋㅋㅋ', 'KoreanParticle'),
#  ('.', 'Punctuation')]

# %% [markdown]
# ##### ♦️3. 실습예제
#   - 한국어 불용어 적용된 명사/형용사/동사를 추출하는 define 만들기

# %%
stopwords = ['있다' ,'되다', '하다', '나']

def okt_pos_tagging(string):
    pos_words = okt.pos(string, stem=True, norm=True)
    words = [word for word, tag in pos_words if tag in {'Noun', 'Adjective', 'Verb'} if word not in stopwords ]
    return words

# %%
okt_pos_tagging('나는 필통을 가지고 있다.')
# Out:
# ['필통', '가지']

# %% [markdown]
# ## 3. 형태소분석 : Kiwi

# %%
# !pip install kiwipiepy
# Out:
# Collecting kiwipiepy
#   Downloading kiwipiepy-0.21.0-cp312-cp312-win_amd64.whl.metadata (1.3 kB)
# Collecting kiwipiepy_model<0.22,>=0.21 (from kiwipiepy)
#   Downloading kiwipiepy_model-0.21.0.tar.gz (35.5 MB)
#      ---------------------------------------- 0.0/35.5 MB ? eta -:--:--
#      --- ------------------------------------ 3.1/35.5 MB 20.6 MB/s eta 0:00:02
#      ---- ----------------------------------- 3.7/35.5 MB 9.1 MB/s eta 0:00:04
#      ----------- --------------------------- 10.2/35.5 MB 16.4 MB/s eta 0:00:02
#      ------------------------ -------------- 22.0/35.5 MB 26.8 MB/s eta 0:00:01
#      ----------------------------- --------- 27.3/35.5 MB 26.6 MB/s eta 0:00:01
#      --------------------------------------- 35.5/35.5 MB 30.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: numpy in c:\users\002\anaconda3\lib\site-packages (from kiwipiepy) (1.26.4)
# Requirement already satisfied: tqdm in c:\users\002\anaconda3\lib\site-packages (from kiwipiepy) (4.66.5)
# Requirement already satisfied: colorama in c:\users\002\anaconda3\lib\site-packages (from tqdm->kiwipiepy) (0.4.6)
# Downloading kiwipiepy-0.21.0-cp312-cp312-win_amd64.whl (2.4 MB)
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ---------------------------------------- 2.4/2.4 MB 67.4 MB/s eta 0:00:00
# Building wheels for collected packages: kiwipiepy_model
#   Building wheel for kiwipiepy_model (setup.py): started
#   Building wheel for kiwipiepy_model (setup.py): finished with status 'done'
#   Created wheel for kiwipiepy_model: filename=kiwipiepy_model-0.21.0-py3-none-any.whl size=35593200 sha256=57e20840d0901a69143a4de2b531fffe238ed9e89e77ec8352c479bffd8c39d5
#   Stored in directory: c:\users\002\appdata\local\pip\cache\wheels\5f\94\81\3e8b1478625f1bdb3b72733dfe3086a8f77a8f25db2b1d746b
# Successfully built kiwipiepy_model
# Installing collected packages: kiwipiepy_model, kiwipiepy
# Successfully installed kiwipiepy-0.21.0 kiwipiepy_model-0.21.0

# %%
from kiwipiepy import Kiwi
kiwi = Kiwi()

# %%
kiwi.tokenize("아버지가 방에 들어가신다")
# Out:
# [Token(form='아버지', tag='NNG', start=0, len=3),
#  Token(form='가', tag='JKS', start=3, len=1),
#  Token(form='방', tag='NNG', start=5, len=1),
#  Token(form='에', tag='JKB', start=6, len=1),
#  Token(form='들어가', tag='VV', start=8, len=3),
#  Token(form='시', tag='EP', start=11, len=1),
#  Token(form='ᆫ다', tag='EF', start=11, len=2)]

# %%
#토큰
token = [i[0] for i in kiwi.tokenize("아버지가 방에 들어가신다")]
token
# Out:
# ['아버지', '가', '방', '에', '들어가', '시', 'ᆫ다']

# %% [markdown]
# ### 3.1 kiwi 불용어 사전 다루기

# %%
from kiwipiepy.utils import Stopwords
stopwords = Stopwords()

# %%
kiwi.tokenize("분석 결과에서 불용어만 제외하고 출력할 수 있다.", stopwords=stopwords)
# Out:
# [Token(form='분석', tag='NNG', start=0, len=2),
#  Token(form='결과', tag='NNG', start=3, len=2),
#  Token(form='불', tag='NNG', start=8, len=1),
#  Token(form='용어', tag='NNG', start=9, len=2),
#  Token(form='제외', tag='NNG', start=13, len=2),
#  Token(form='출력', tag='NNG', start=18, len=2),
#  Token(form='있', tag='VA', start=24, len=1)]

# %%
stopwords.stopwords
# Out:
# {('ᆫ', 'ETM'),
#  ('ᆫ', 'JX'),
#  ('ᆫ다', 'EF'),
#  ('ᆯ', 'ETM'),
#  ('가', 'JKS'),
#  ('같', 'VA'),
#  ('것', 'NNB'),
#  ('게', 'EC'),
#  ('겠', 'EP'),
#  ('고', 'EC'),
#  ('고', 'JKQ'),
#  ('과', 'JC'),
#  ('과', 'JKB'),
#  ('그', 'MM'),
#  ('그', 'NP'),
#  ('기', 'ETN'),
#  ('까지', 'JX'),
#  ('나', 'NP'),
#  ('년', 'NNB'),
#  ('는', 'ETM'),
#  ('는', 'JX'),
#  ('다', 'EC'),
#  ('다', 'EF'),
#  ('다고', 'EC'),
#  ('다는', 'ETM'),
#  ('대하', 'VV'),
#  ('더', 'MAG'),
#  ('던', 'ETM'),
#  ('도', 'JX'),
#  ('되', 'VV'),
#  ('되', 'XSV'),
#  ('들', 'XSN'),
#  ('등', 'NNB'),
#  ('따르', 'VV'),
#  ('때', 'NNG'),
#  ('때문', 'NNB'),
#  ('라', 'EC'),
#  ('라는', 'ETM'),
#  ('로', 'JKB'),
#  ('를', 'JKO'),
#  ('만', 'JX'),
#  ('만', 'NR'),
#  ('말', 'NNG'),
#  ('며', 'EC'),
#  ('면', 'EC'),
#  ('면서', 'EC'),
#  ('명', 'NNB'),
#  ('받', 'VV'),
#  ('보', 'VV'),
#  ('부터', 'JX'),
#  ('사람', 'NNG'),
#  ('성', 'XSN'),
#  ('수', 'NNB'),
#  ('아니', 'VCN'),
#  ('않', 'VX'),
#  ('어', 'EC'),
#  ('어', 'EF'),
#  ('어서', 'EC'),
#  ('어야', 'EC'),
#  ('없', 'VA'),
#  ('었', 'EP'),
#  ('에', 'JKB'),
#  ('에게', 'JKB'),
#  ('에서', 'JKB'),
#  ('와', 'JC'),
#  ('와', 'JKB'),
#  ('우리', 'NP'),
#  ('원', 'NNB'),
#  ('월', 'NNB'),
#  ('위하', 'VV'),
#  ('으로', 'JKB'),
#  ('은', 'ETM'),
#  ('은', 'JX'),
#  ('을', 'ETM'),
#  ('을', 'JKO'),
#  ('의', 'JKG'),
#  ('이', 'JKC'),
#  ('이', 'JKS'),
#  ('이', 'MM'),
#  ('이', 'NP'),
#  ('이', 'VCP'),
#  ('일', 'NNB'),
#  ('일', 'NNG'),
#  ('있', 'VV'),
#  ('있', 'VX'),
#  ('적', 'XSN'),
#  ('제', 'XPN'),
#  ('주', 'VX'),
#  ('중', 'NNB'),
#  ('지', 'EC'),
#  ('지', 'VX'),
#  ('지만', 'EC'),
#  ('지역', 'NNG'),
#  ('통하', 'VV'),
#  ('하', 'VV'),
#  ('하', 'VX'),
#  ('하', 'XSA'),
#  ('하', 'XSV'),
#  ('한', 'MM'),
#  ('화', 'XSN')}

# %%
stopwords.add("분석")

# %% [markdown]
# ### 3.2 kiwi 띄어쓰기 및 문장 분리

# %%
kiwi.space('띄어쓰기없이작성된텍스트이다')
# Out:
# '띄어쓰기 없이 작성된 텍스트이다'

# %%
kiwi.split_into_sents('오늘은텍스트마이닝시간입니다다음주는다른것을배워볼께요')
# Out:
# [Sentence(text='오늘은텍스트마이닝시간입니다', start=0, end=14, tokens=None, subs=[]),
#  Sentence(text='다음주는다른것을배워볼께요', start=14, end=27, tokens=None, subs=[])]

# %%
kiwi.split_into_sents('오늘은텍스트마이닝시간입니다다음주는다른것을배워볼께요')[0][0]
# Out:
# '오늘은텍스트마이닝시간입니다'

# %%
import pandas as pd

df = pd.read_pickle("/Users/harry/LG DX SCHOOL/dx-project/텍스트 마이닝/merged.pkl")
df
# Out:
#                                   title  \
# 0     아내한테 씻는거 까지 얘기해야하나요제왕절개 후 샤워 질문이요
# 1                   결혼식 답례품마라톤 당일 아침 샤워
# 2    원정 수영장 추천해주세요독감주사 샤워 바로 해도 괜찮은가요??
# 3      전자담배 피는 남자들남부 라페스타 힐튼 샤워필터 필수!!!
# 4        남친한테 이런걸로 뭐라하면 쪼잔한가?매일굽는 샤워도우~
# ..                                  ...
# 834                                 NaN
# 835                                 NaN
# 836                                 NaN
# 837                                 NaN
# 838                                 NaN
#
#                                                content  \
# 0    안 씻으면 냄새나는 타입인데 야근이 많은 직종이라 땀 안 흘렸다고 안씻고 자는데 냄...
# 1    브라이덜샤워 해주고(간단히)웨딩드레스 골라준 댓가로 이거 받았어요상사는 따로 챙겨주...
# 2    서울이면 좋고요채광 잘들고 샤워시설 깔끔한 곳이면 좋겠어요독감주사 샤워 바로 해도 ...
# 3    전담 보통 화장실이나 샤워실에서도 많이펴...?여친한테 안걸리려고..?북부 크라운 ...
# 4    내가 유일하게 관심있고 좋아하는게 샤워용품 모으는거야샤워젤 바디워시 바디로션 바디스...
# ..                                                 ...
# 834                                                NaN
# 835                                                NaN
# 836                                                NaN
# 837                                                NaN
# 838                                                NaN
#
#                                                comment                  date
# 0    ['아니 근데 침대에 누울 땐 씻고 누워야 하는 거 아니야?', '냄새난다고해', ...  3시간2025.11.14. 15:08
# 1    ['장기적으로 보면 형한테 이득이긴 한데\n사진보니 개빡치기는 하네', 'ㄹㅇ 저게...  4시간2025.11.07. 15:11
# 2    []['독감주사 샤워 바로하기 보다는 좀 찝찝해도 하루 참고 내일 하세요..', '...   어제2025.11.11. 10:53
# 3    ['전담도 냄새나는데 전담은 ㄱㅊ아하면서 피는사람존많', '전담은 냄새덜나니까 가능...   어제2025.11.11. 18:45
# 4    ['투껑 닫으라 정도까진 ㄱㅊ할듯', '투껑은 뭐임 뚜껑 두개? Two껑?', '지...   어제2025.11.12. 15:21
# ..                                                 ...                   ...
# 834                                                NaN                   NaN
# 835                                                NaN                   NaN
# 836                                                NaN                   NaN
# 837                                                NaN                   NaN
# 838                                                NaN                   NaN
#
# [839 rows x 4 columns]
